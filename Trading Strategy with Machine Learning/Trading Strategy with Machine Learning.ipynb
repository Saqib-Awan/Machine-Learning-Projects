# %% [markdown]
# ## Trading Strategy with Machine Learning

# %% [markdown]
# ### importing necessary libraries

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
plt.style.use("dark_background")

# %%
appl = pd.read_csv("AAPL.csv")
appl
# Out:
#            Date  Open Price  High Price   Low Price  Close Price  \
# 0     5/27/2014   87.982857   89.408569   87.947144    89.375717
# 1     5/28/2014   89.431427   89.975716   89.111427    89.144287
# 2     5/29/2014   89.692856   90.981430   89.681427    90.768570
# 3     5/30/2014   91.139999   92.024284   89.842857    90.428574
# 4      6/2/2014   90.565712   90.690002   88.928574    89.807144
# ...         ...         ...         ...         ...          ...
# 1505  5/18/2020  313.170013  316.500000  310.320007   314.959991
# 1506  5/19/2020  315.029999  318.519989  313.010010   313.140015
# 1507  5/20/2020  316.679993  319.519989  316.519989   319.230011
# 1508  5/21/2020  318.660004  320.890015  315.869995   316.850006
# 1509  5/22/2020  315.769989  319.230011  315.350006   318.890015
#
#       Adj Close Price     Volume
# 0           80.948952   87216500
# 1           80.739334   78870400
# 2           82.210480   94118500
# 3           81.902557  141005200
# ...

# %% [markdown]
# ### Visualizing Data

# %%
plt.figure(figsize=(12, 5))
plt.plot(appl['Adj Close Price'], label='Appl')
plt.title('Appl Adj Close Price History')
plt.xlabel("May 27,2014 - May 25,2020 ")
plt.ylabel("Adj Close Price USD ($)")
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ### Moving Average with 30 day window

# %%
sma30 = pd.DataFrame()
sma30['Adj Close Price'] = appl['Adj Close Price'].rolling(window=30).mean()
sma30
# Out:
#       Adj Close Price
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1505       287.864806
# 1506       289.577426
# 1507       291.594106
# 1508       293.310716
# 1509       295.031499
#
# [1510 rows x 1 columns]

# %% [markdown]
# ### Moving Average with 100 day window

# %%
sma100 = pd.DataFrame()
sma100['Adj Close Price'] = appl['Adj Close Price'].rolling(window=100).mean()
sma100
# Out:
#       Adj Close Price
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1505       289.734840
# 1506       290.037927
# 1507       290.345799
# 1508       290.630966
# 1509       290.919420
#
# [1510 rows x 1 columns]

# %% [markdown]
# ### Visualizing the new data

# %%
plt.figure(figsize=(12,5))
plt.plot(appl['Adj Close Price'], label='Appl')
plt.plot(sma30['Adj Close Price'], label='SMA30')
plt.plot(sma100['Adj Close Price'], label='SMA100')
plt.title("Appl Adj. Close Price History")
plt.xlabel('May 27,2014 - May 25,2020')
plt.ylabel('Adj. Close Price USD($)')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Creating dataframe to store new data

# %%
data = pd.DataFrame()
data['appl'] = appl['Adj Close Price']
data['SMA30'] = sma30['Adj Close Price']
data['SMA100'] = sma100['Adj Close Price']
data
# Out:
#             appl       SMA30      SMA100
# 0      80.948952         NaN         NaN
# 1      80.739334         NaN         NaN
# 2      82.210480         NaN         NaN
# 3      81.902557         NaN         NaN
# 4      81.339699         NaN         NaN
# ...          ...         ...         ...
# 1505  314.959991  287.864806  289.734840
# 1506  313.140015  289.577426  290.037927
# 1507  319.230011  291.594106  290.345799
# 1508  316.850006  293.310716  290.630966
# 1509  318.890015  295.031499  290.919420
#
# [1510 rows x 3 columns]

# %% [markdown]
# ### Creating a function which tells us when to buy or sell

# %%
def buySell(data):
  sigPriceBuy = []
  sigPriceSell = []
  flag = -1
  for i in range(len(data)):
    if data ['SMA30'][i] > data['SMA100'][i]:
      if flag != 1:
        sigPriceBuy.append(data['appl'][i])
        sigPriceSell.append(np.nan)
        flag = 1
      else:
        sigPriceBuy.append(np.nan)
        sigPriceSell.append(np.nan)
    elif data['SMA30'][i] < data['SMA100'][i]:
      if flag != 0:
        sigPriceBuy.append(np.nan)
        sigPriceSell.append(data['appl'][i])
        flag = 0
      else:
        sigPriceBuy.append(np.nan)
        sigPriceSell.append(np.nan)
    else:
      sigPriceBuy.append(np.nan)
      sigPriceSell.append(np.nan)
  return(sigPriceBuy, sigPriceSell)

# %%
buySell = buySell(data)
data['Buy Signal Price'] = buySell[0]
data['Sell Signal Price'] = buySell[1]
# To show the data
data
# Out:
#             appl       SMA30      SMA100  Buy Signal Price  Sell Signal Price
# 0      80.948952         NaN         NaN               NaN                NaN
# 1      80.739334         NaN         NaN               NaN                NaN
# 2      82.210480         NaN         NaN               NaN                NaN
# 3      81.902557         NaN         NaN               NaN                NaN
# 4      81.339699         NaN         NaN               NaN                NaN
# ...          ...         ...         ...               ...                ...
# 1505  314.959991  287.864806  289.734840               NaN                NaN
# 1506  313.140015  289.577426  290.037927               NaN                NaN
# 1507  319.230011  291.594106  290.345799        319.230011                NaN
# 1508  316.850006  293.310716  290.630966               NaN                NaN
# 1509  318.890015  295.031499  290.919420               NaN                NaN
#
# [1510 rows x 5 columns]

# %% [markdown]
# ### Visualizing the buy sell strategy

# %%
plt.style.use('classic')
plt.figure(figsize=(12,5))
plt.plot(data['appl'], label='Appl', alpha=0.35)
plt.plot(data['SMA30'], label='SMA30', alpha=0.35)
plt.plot(data['SMA100'],label='SMA100', alpha=0.35)
plt.scatter(data.index, data['Buy Signal Price'], label ='Buy', marker='^',color='green')
plt.scatter(data.index, data['Sell Signal Price'],label='Sell', marker='v', color='red')
plt.title('Appl Adj. Close Price History Buy and Sell Signals')
plt.xlabel("May 27,2014 - May 25,2020")
plt.ylabel("Adj Close Price USD($)")
plt.legend(loc='upper left')
plt.show()
